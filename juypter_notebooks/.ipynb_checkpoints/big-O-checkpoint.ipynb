# %%
import pprint
import numpy as np
from memory_profiler import profile
import matplotlib.pyplot as plt
from real_time_deanonymization import get_frames

# %% [markdown]
# # Timing of algorithm by increasing packet number

# %%
def run_test(number_of_packets):
    results = []
    for x in number_of_packets:
        result  = %timeit -r 10 -n 3 -c -o get_frames(x); 
        results.append(result)
    return results

# %%
number_of_packets = [1,5,10,50,100,250,500,1000,5000,10000,20000,30000,40000,50000,60000
                    ,70000,80000,90000,100000];

results = run_test(number_of_packets)

worst_case_times = [x.worst for x in results]
stdev = [x.stdev for x in results]

print("Worst case times are {}".format(worst_case_times))

fig, axs = plt.subplots(ncols = 2,nrows = 1, figsize=(10,4),squeeze=False)
axs[0][0].plot(number_of_packets, worst_case_times)
axs[0][0].set_title('Execution time vs number of packets')
axs[0][0].set_xlabel("Number of Packets")
axs[0][0].set_ylabel("Time (ms)");

axs[0][1].plot(number_of_packets, stdev)
axs[0][1].set_title('Stantard Deviation vs number of packets')
axs[0][1].set_xlabel("Number of Packets")
axs[0][1].set_ylabel("Stantard Deviation");
# Out:
# 2.87 ms ± 366 µs per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 3.23 ms ± 463 µs per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 3.65 ms ± 596 µs per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 3.44 ms ± 839 µs per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 3.54 ms ± 408 µs per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 4.77 ms ± 356 µs per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 6.71 ms ± 1.35 ms per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 9.26 ms ± 407 µs per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 29.4 ms ± 1.61 ms per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 66.5 ms ± 790 µs per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 128 ms ± 1.91 ms per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 249 ms ± 3.48 ms per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 411 ms ± 1.94 ms per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 525 ms ± 33.4 ms per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 668 ms ± 9.24 ms per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 879 ms ± 32.1 ms per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 1.05 s ± 6.94 ms per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 1.22 s ± 8.95 ms per loop (mean ± std. dev. of 10 runs, 3 loops each)
# 1.52 s ± 19.1 ms per loop (mean ± std. dev. of 10 runs, 3 loops each)
# Worst case times are [0.003667333333339684, 0.00431066666665932, 0.0045623333333348155, 0.005753000000008039, 0.004377999999993183, 0.005327666666668544, 0.010591666666660634, 0.009979333333338522, 0.033749666666684185, 0.06808500000001534, 0.1329750000000066, 0.25680633333333464, 0.4160320000000108, 0.6248213333333297, 0.6946286666666689, 0.9491013333333361, 1.064421333333333, 1.2285263333333394, 1.5511189999999904]

# %%
number_of_packets = [x for x in range(5000,5010)]
results = run_test(number_of_packets)
worst_case_times = [x.worst for x in results]
stdev = [x.stdev for x in results]


plt.figure()
plt.title("Stantard Deviation vs number of packets")
plt.plot(number_of_packets, worst_case_times, stdev, linestyle='None',capsize=10, fmt="o")
plt.xlabel("Number of Packets")

# %% [markdown]
# # Memory profiling by increasing number of packets

# %%
# %load_ext memory_profiler
number_of_packets = [10000,20000,30000,40000,50000,60000
                    ,70000,80000,90000,100000];

results = []
for x in number_of_packets:
    result  =  %memit -o -r 10 get_frames(x); 
    results.append(result)
# Out:
# peak memory: 158.73 MiB, increment: 0.28 MiB
# peak memory: 166.08 MiB, increment: 7.35 MiB
# peak memory: 181.07 MiB, increment: 19.68 MiB
# peak memory: 196.26 MiB, increment: 30.16 MiB
# peak memory: 211.26 MiB, increment: 41.05 MiB
# peak memory: 226.31 MiB, increment: 50.36 MiB
# peak memory: 241.34 MiB, increment: 61.14 MiB
# peak memory: 256.46 MiB, increment: 69.36 MiB
# peak memory: 257.02 MiB, increment: 68.28 MiB
# peak memory: 257.47 MiB, increment: 95.21 MiB

# %%
memory_usage = [(np.array(x.mem_usage).mean() - x.baseline) for x in results]
#plt.plot(number_of_packets, memory_usage)
plt.figure(figsize=(20, 3))  
plt.bar([str(x)for x in number_of_packets],memory_usage, alpha=0.5)
# Out:
# <BarContainer object of 10 artists>

# %%
memory_usage = [np.array(x.mem_usage).mean() for x in results]
plt.plot(number_of_packets, memory_usage)

# %% [markdown]
# # Time-based memory usage

# %%
# %%bash
# cd ~/Documents/3rd-Year-Project
# number_of_packets=(1 5 10 50 100 250 500 1000 5000 10000 20000 30000 40000 50000 60000 70000 80000 90000 100000)
# for x in "${number_of_packets[@]}"
# do
#     echo $x
#     mprof run real_time_deanonymization.py -n $x
#     match=$(ls | grep "mprofile_[0-9]*.dat")
#     mv $match  ~/Documents/3rd-Year-Project/time_based_tests/$match
# done
# Out:
# 1
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 5
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 10
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 50
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 100
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 250
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 500
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 1000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 5000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 10000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 20000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 30000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 40000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 50000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 60000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 70000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 80000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 90000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# 100000
# mprof: Sampling memory every 0.1s
# running as a Python program...
# mv: target 'mprofile_20190226122424.dat' is not a directory
# mv: target 'mprofile_20190226122426.dat' is not a directory
# mv: target 'mprofile_20190226122428.dat' is not a directory
# mv: target 'mprofile_20190226122430.dat' is not a directory
# mv: target 'mprofile_20190226122432.dat' is not a directory
# mv: target 'mprofile_20190226122434.dat' is not a directory
# mv: target 'mprofile_20190226122436.dat' is not a directory
# mv: target 'mprofile_20190226122438.dat' is not a directory
# mv: target 'mprofile_20190226122440.dat' is not a directory
# mv: target 'mprofile_20190226122442.dat' is not a directory
# mv: target 'mprofile_20190226122444.dat' is not a directory
# mv: target 'mprofile_20190226122446.dat' is not a directory
# mv: target 'mprofile_20190226122448.dat' is not a directory
# mv: target 'mprofile_20190226122450.dat' is not a directory
# mv: target 'mprofile_20190226122453.dat' is not a directory
# mv: target 'mprofile_20190226122456.dat' is not a directory
# mv: target 'mprofile_20190226122459.dat' is not a directory
# mv: target 'mprofile_20190226122502.dat' is not a directory
# mv: target 'mprofile_20190226122505.dat' is not a directory

# %%
# %%bash
# cd ~/Documents/3rd-Year-Project
# mprof run real_time_deanonymization.py -n 100000
# match=$(ls | grep "mprofile_[0-9]*.dat")
# mv $match  ~/Documents/3rd-Year-Project/time_based_tests/$match
# Out:
# mprof: Sampling memory every 0.1s
# running as a Python program...

# %%
# %%bash
# cd ~/Documents/3rd-Year-Project/time_based_tests/
# mprof plot -o result.png --backend agg
# Out:
# Using last profile data.

# %% [markdown]
# ![alt text](time_based_tests/result.png "Logo Title Text 1")

# %% [markdown]
# # Time/Space Analysis by number of Clusters

# %% [markdown]
# See other notebook
